# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)
import re
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from scipy.stats import chi2_contingency
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # 0.Importing from cleaned data notebook
#
#
# For now, we are working on three files separately. We will work on the regional information, with the count column as a target column. After cleaning we will run a linear regression to attempt to predict number of cases.
# The same will be done at a country level with the demo trends files. Again, the count will be our target variable.
#
# Finally, the victims data will be used for some clustering exploration. Similarly, some clustering will be run on the regional demographics.
#
# <br/>
# 1. We will start with exploration of the region information<br/>
# - correlation between column <br/>
# - distribution <br/>
# - outliers
# <br/>
# 2. We will continue with exploration of country <br/>
# - correlation between column <br/>
# 3. Encoding and Standardization <br/>
# - standardize data regions <br/>
# - encode data victims <br/>
# 4. Exploration of Victims
# 5. Save for clustering and models > new notebook <br/>

# %%
victims = pd.read_csv('victims_cleaned.csv')

# %%
regions = pd.read_csv('regions_cleaned.csv')

# %%
country_death = pd.read_csv('country_femicides.csv')

# %%
victims.head()
# Out:
#    Unnamed: 0   age        date    prov_name perpetrator_en_new  \
# 0           0  18.0  2017-12-31     istanbul          boyfriend
# 1           1  17.0  2017-12-31       burdur          boyfriend
# 2           2  38.0  2017-12-30         bolu          boyfriend
# 3           3  53.0  2017-12-27       ankara          boyfriend
# 4           4  22.0  2017-12-25   diyarbakir            partner
#
#              excuses_cat
# 0                Unknown
# 1  Separation & Jealousy
# 2                  Other
# 3  Separation & Jealousy
# 4  Separation & Jealousy

# %%
victims = victims.drop('Unnamed: 0', axis =1)

# %%
regions.head()
# Out:
#    Unnamed: 0  prov_code  year  all_wm_prov  knows_wm_prov  total_pop  \
# 0           0          1  2010         20.0           19.0  2085225.0
# 1           1          1  2011         15.0           15.0  2108805.0
# 2           2          1  2012          9.0            9.0  2125635.0
# 3           3          1  2013          7.0            7.0  2149260.0
# 4           4          1  2014         14.0           14.0  2165595.0
#
#    ethnic_turkish  ethnic_kurdish  ln_casualty  ln_gdppc_cons  \
# 0        82.03772       13.370917     3.178054       4.187798
# 1        82.03772       13.370917     3.178054       4.270533
# 2        82.03772       13.370917     3.178054       4.310695
# 3        82.03772       13.370917     3.178054       4.350712
# 4        82.03772       13.370917     3.178054       4.379060
#
#    divorce_rate_ma5  mosques_perk  ceasefire  fm_diff_educ  count  \
# 0             1.458      0.606649          0     -0.062882   20.0
# 1             1.532      0.599866          0     -0.068188   15.0
# 2             1.632      0.640750          0     -0.067100    9.0
# 3             1.712      0.651852          1     -0.066711    7.0
# 4             1.790      0.654324          1     -0.067147   14.0
#
#    pol_attitude
# 0          91.6
# 1          91.6
# 2          91.6
# 3          79.8
# 4          79.8

# %%
regions = regions.drop('Unnamed: 0', axis =1)

# %% [markdown]
# We also drop the year, as it is not needed from now on

# %%
regions = regions.drop('year', axis =1)

# %%
regions.dtypes
# Out:
# prov_code             int64
# all_wm_prov         float64
# knows_wm_prov       float64
# total_pop           float64
# ethnic_turkish      float64
# ethnic_kurdish      float64
# ln_casualty         float64
# ln_gdppc_cons       float64
# divorce_rate_ma5    float64
# mosques_perk        float64
# ceasefire             int64
# fm_diff_educ        float64
# count               float64
# pol_attitude        float64
# dtype: object

# %% [markdown]
# # 1. Region Data

# %% [markdown]
# #### Splitting numericals and categoricals
#
# Ceasefire would appear to be the only categoricals when checking for 10+ values as min. requirement for numericals.
#
# It takes the value of 1 in years 2013 and 2014, and 0 otherwise. This variable is interacted with Civil War Exposure. Basically it is already encoded and we can keep it in the numericals.

# %%
num = regions
num.head()
# Out:
#    prov_code  all_wm_prov  knows_wm_prov  total_pop  ethnic_turkish  \
# 0          1         20.0           19.0  2085225.0        82.03772
# 1          1         15.0           15.0  2108805.0        82.03772
# 2          1          9.0            9.0  2125635.0        82.03772
# 3          1          7.0            7.0  2149260.0        82.03772
# 4          1         14.0           14.0  2165595.0        82.03772
#
#    ethnic_kurdish  ln_casualty  ln_gdppc_cons  divorce_rate_ma5  mosques_perk  \
# 0       13.370917     3.178054       4.187798             1.458      0.606649
# 1       13.370917     3.178054       4.270533             1.532      0.599866
# 2       13.370917     3.178054       4.310695             1.632      0.640750
# 3       13.370917     3.178054       4.350712             1.712      0.651852
# 4       13.370917     3.178054       4.379060             1.790      0.654324
#
#    ceasefire  fm_diff_educ  count  pol_attitude
# 0          0     -0.062882   20.0          91.6
# 1          0     -0.068188   15.0          91.6
# 2          0     -0.067100    9.0          91.6
# 3          1     -0.066711    7.0          79.8
# 4          1     -0.067147   14.0          79.8

# %% [markdown]
# # Exploration on Numericals

# %%
for i in num.columns:
    print(num[i].describe())
# Out:
# count    648.000000
# mean      41.000000
# std       23.398966
# min        1.000000
# 25%       21.000000
# 50%       41.000000
# 75%       61.000000
# max       81.000000
# Name: prov_code, dtype: float64
# count    648.000000
# mean       3.030864
# std        5.068218
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        4.000000
# max       46.000000
# Name: all_wm_prov, dtype: float64
# count    648.000000
# mean       2.915123
# std        4.868333
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max       42.000000
# Name: knows_wm_prov, dtype: float64
# count    6.480000e+02
# mean     9.534026e+05
# std      1.706082e+06
# min      7.441200e+04
# 25%      2.808055e+05
# 50%      5.131070e+05
# 75%      9.948722e+05
# max      1.502923e+07
# Name: total_pop, dtype: float64
# count    648.000000
# mean      75.425493
# std       33.867957
# min        0.000000
# 25%       62.074455
# 50%       94.709680
# 75%       99.407780
# max      100.000000
# Name: ethnic_turkish, dtype: float64
# count    648.000000
# mean      21.467349
# std       32.434790
# min        0.000000
# 25%        0.000000
# 50%        3.169473
# 75%       25.884853
# max      100.000000
# Name: ethnic_kurdish, dtype: float64
# count    648.000000
# mean       2.345763
# std        2.623615
# min        0.000000
# 25%        0.000000
# 50%        1.098612
# 75%        4.204693
# max        8.323852
# Name: ln_casualty, dtype: float64
# count    648.000000
# mean       4.344408
# std        0.342109
# min        3.463987
# 25%        4.108124
# 50%        4.336241
# 75%        4.566989
# max        5.339387
# Name: ln_gdppc_cons, dtype: float64
# count    648.000000
# mean       1.283133
# std        0.616719
# min        0.114000
# 25%        0.857000
# 50%        1.342000
# 75%        1.709000
# max        2.754000
# Name: divorce_rate_ma5, dtype: float64
# count    648.000000
# mean       1.843475
# std        1.160641
# min        0.226302
# 25%        1.120346
# 50%        1.577232
# 75%        2.132194
# max        7.162153
# Name: mosques_perk, dtype: float64
# count    648.000000
# mean       0.250000
# std        0.433347
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.250000
# max        1.000000
# Name: ceasefire, dtype: float64
# count    648.000000
# mean      -0.100884
# std        0.028900
# min       -0.184529
# 25%       -0.119214
# 50%       -0.099548
# 75%       -0.080654
# max       -0.043720
# Name: fm_diff_educ, dtype: float64
# count    438.000000
# mean       4.143836
# std        5.334988
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       46.000000
# Name: count, dtype: float64
# count    648.000000
# mean      63.620000
# std       56.496695
# min      -85.040000
# 25%       79.800000
# 50%       79.800000
# 75%       91.600000
# max       91.600000
# Name: pol_attitude, dtype: float64

# %% [markdown]
# #### Check Multicollinearity

# %%
correlations_matrix = num.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
regions
# Out:
#      prov_code  all_wm_prov  knows_wm_prov  total_pop  ethnic_turkish  \
# 0            1         20.0           19.0  2085225.0        82.03772
# 1            1         15.0           15.0  2108805.0        82.03772
# 2            1          9.0            9.0  2125635.0        82.03772
# 3            1          7.0            7.0  2149260.0        82.03772
# 4            1         14.0           14.0  2165595.0        82.03772
# ..         ...          ...            ...        ...             ...
# 643         81          2.0            2.0   351509.0        87.50000
# 644         81          2.0            2.0   355549.0        87.50000
# 645         81          2.0            2.0   360388.0        87.50000
# 646         81          3.0            3.0   370371.0        87.50000
# 647         81          2.0            2.0   377610.0        87.50000
#
#      ethnic_kurdish  ln_casualty  ln_gdppc_cons  divorce_rate_ma5  \
# 0         13.370917     3.178054       4.187798             1.458
# 1         13.370917     3.178054       4.270533             1.532
# 2         13.370917     3.178054       4.310695             1.632
# 3         13.370917     3.178054       4.350712             1.712
# 4         13.370917     3.178054       4.379060             1.790
# ..              ...          ...            ...               ...
# 643       12.500000     0.000000       4.536124             1.454
# 644       12.500000     0.000000       4.592223             1.572
# 645       12.500000     0.000000       4.680219             1.730
# 646       12.500000     0.000000       4.654947             1.850
# 647       12.500000     0.000000       4.684415             1.822
#
#      mosques_perk  ceasefire  fm_diff_educ  count  pol_attitude
# 0        0.606649          0     -0.062882   20.0         91.60
# 1        0.599866          0     -0.068188   15.0         91.60
# 2        0.640750          0     -0.067100    9.0         91.60
# 3        0.651852          1     -0.066711    7.0         79.80
# 4        0.654324          1     -0.067147   14.0         79.80
# ..            ...        ...           ...    ...           ...
# 643      1.894688          1     -0.104740    2.0         79.80
# 644      1.881597          1     -0.103488    2.0         79.80
# 645      1.856333          0     -0.102752    2.0         79.80
# 646      1.833297          0     -0.095931    3.0         79.80
# 647      1.814041          0     -0.094149    2.0        -85.04
#
# [648 rows x 14 columns]

# %% [markdown]
# ### Dropping columns
#
# Based on the heatmap, and the fact we have imported the count per region. We drop the columns with information about cases country wide

# %%
regions = regions.drop(['all_wm_prov', 'knows_wm_prov'], axis = 1)

# %% [markdown]
# *Multicollinearity shows generally values above 0.50. It is good to also check the data with VIF.*

# %%
vif = {}
num_vif = num.copy()
num_vif= add_constant(num)
for i in np.arange(num_vif.shape[1]):
    column_name = num_vif.columns[i]
    value = variance_inflation_factor(np.array(num_vif), i)
    vif[column_name] = value
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-18-51b62b402c8a> in <module>
#       4 for i in np.arange(num_vif.shape[1]):
#       5     column_name = num_vif.columns[i]
# ----> 6     value = variance_inflation_factor(np.array(num_vif), i)
#       7     vif[column_name] = value
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     190     mask = np.arange(k_vars) != exog_idx
#     191     x_noti = exog[:, mask]
# --> 192     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     193     vif = 1. / (1. - r_squared_i)
#     194     return vif
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     131             exog_max = np.max(self.exog, axis=0)
#     132             if not np.isfinite(exog_max).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#     135             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %% [markdown]
# #### Correlation between numerical variables and target

# %%
for i in num:
    if i != 'count':
        sns.boxplot(x="count", y=i, data = num)
        plt.show()
    else:
        continue
#result: here it is possible to see the relationship between q3_balance and the target variable

# %%
sns.color_palette("coolwarm", as_cmap=True)
fig,axs = plt.subplots(ncols=3, nrows=4, figsize =(15, 25))
plt.subplots_adjust(right=1.5)

for i, feature in enumerate(num, 1):    
    plt.subplot(4, 3, i)
    sns.scatterplot(x=feature, y='count', palette = 'coolwarm', size='price', data=num)
    plt.xlabel('{}'.format(feature), size=15)
    plt.ylabel('price', size=15, labelpad=12.5)
plt.show()

# %%
for i in range(num.shape[1]):
    sns.histplot(num[num.columns[i]], bins=40)
    plt.show()

# %% [markdown]
# *Replacing low frequency values?

# %% [markdown]
# #### Target Distribution
